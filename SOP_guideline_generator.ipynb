# %% [markdown]
# ### Importing necessary libraries

# %%
from types import SimpleNamespace
import json
import re
import time
from pandas import json_normalize
from pprint import pprint
from IPython.core.display import HTML
from tqdm import tqdm
tqdm.pandas()

from dotenv import load_dotenv
load_dotenv()

from openai import OpenAI
client = OpenAI()

# %% [markdown]
# ### Step 1: We need to ask users for their input on the scope of the guideline - their responses would be used as prompts into the model

# %%
# objective = input("What is the objective or purpose of the guideline?")

# author = input("Who is the author?")

# audience = input("Who is the intended audience?")

# format = input("What would be your preferred format of the guideline?")

# instructions = input("Please provide necessary and additional details that are needed to complete each step.")

# %%
objective = "To generate clear instructions for data labellers for image annotation"

author = "I am a Project Manager for the data science use case"

audience = "It is intended for data labellers"

format = "It should be in a table format, with an additional column for images as example illustration"

instructions = "For each image, please annotate cars and trees with their corresponding given labels. Do not annotate taxis as cars."

# %% [markdown]
# ### Step 2: Let's start by setting up the variables we need to input into the model

# %% [markdown]
# For now, lets build the SOP generator with a specific use case in mind - in this case it would be the data labelling case study
#
# what are the variables that I need to develop a data annotation guideline?
#
# 1. we need the model duh
# 2. the messages are key requirements as well
# 3. the context should be set as well, given to the system

# %%
model_input = SimpleNamespace()

model_input.model_id = "gpt-4-1106-preview"
model_input.messages = [objective,author,audience,format,instructions]
model_input.context = "You are an expert Standard Operating Procedure (SOP) generator in a JSON table format.\n \
    Make sure that the instructions given are clear and comprehensive, good enough to generate images as well."

# %%
model_input
# Out:
# namespace(model_id='gpt-4-1106-preview',
#           messages=['To generate clear instructions for data labellers for image annotation',
#                     'I am a Project Manager for the data science use case',
#                     'It is intended for data labellers',
#                     'It should be in a table format, with an additional column for images as example illustration',
#                     'For each image, please annotate cars and trees with their corresponding given labels. Do not annotate taxis as cars.'],
#           context='You are an expert Standard Operating Procedure (SOP) generator in a JSON table format.\n     Make sure that the instructions given are clear and comprehensive, good enough to generate images as well.')

# %% [markdown]
# ### Step 3: Next to define a function that enables multi-step conversation

# %%
def GetMessageMemory(NewQuestion, PreviousResponse, systemContext):
    if PreviousResponse is not None:
        response = client.chat.completions.create(
            model=model_input.model_id,
            response_format={ "type": "json_object" },
            messages=[
                {"role": "system", "content": systemContext},
                {"role": "user", "content": NewQuestion},
                {"role": "assistant", "content": PreviousResponse},
            ],
            temperature=0,
            seed=42
            )
    else:
        response = client.chat.completions.create(
            model=model_input.model_id,
            response_format={ "type": "json_object" },
            messages=[
                {"role": "system", "content": systemContext},
                {"role": "user", "content": NewQuestion}
            ],
            temperature=0,
            seed=42
            )

    return response.choices[0].message.content

# %%
last_response = None

for question in tqdm(model_input.messages):
    chat_response = GetMessageMemory(question, last_response, model_input.context)
    # pprint(chat_response)
    last_response = chat_response
# Out:
# 100%|██████████| 5/5 [04:51<00:00, 58.22s/it]

# %%
json_response = json.loads(last_response)

json_response
# Out:
# {'SOP_Table': {'Title': 'Standard Operating Procedure for Image Annotation',
#   'Purpose': 'To provide clear guidelines for annotating images with cars and trees while excluding taxis from the car category.',
#   'Scope': 'This SOP applies to all image annotators tasked with labeling images for machine learning and computer vision training datasets.',
#   'Procedure': [{'Step_Number': '1',
#     'Description': 'Open Annotation Tool',
#     'Instructions': 'Launch the image annotation software and load the image to be annotated.',
#     'Image_Example': 'open_annotation_tool.jpg'},
#    {'Step_Number': '2',
#     'Description': 'Identify Objects',
#     'Instructions': 'Carefully examine the image to identify all instances of cars and trees. Remember not to annotate taxis as cars.',
#     'Image_Example': 'identify_objects.jpg'},
#    {'Step_Number': '3',
#     'Description': 'Annotate Cars',
#     'Instructions': "Use the 'Car' label to annotate all vehicles that are not taxis. Draw a bounding box around each car, ensuring it fits the object as closely as possible without including background elements.",
#     'Image_Example': 'annotate_cars.jpg'},
#    {'Step_Number': '4',
#     'Description': 'Annotate Trees',
#     'Instructions': "Use the 'Tree' label to annotate all visible trees in the image. Draw a bounding box or use polygonal segmentation to outline the full extent of the tree, including branches and foliage.",
#     'Image_Example': 'annotate_trees.jpg'},
#    {'Step_Number': '5',
#     'Description': 'Exclude Taxis',
#     'Instructions': 'Do not annotate taxis. Taxis can typically be identified by their distinct color (often yellow) and markings. If unsure, refer to local taxi identification guidelines.',
#     'Image_Example': 'exclude_taxis.jpg'},
#    {'Step_Number': '6',
#     'Description': 'Review Annotations',
#     'Instructions': 'Review all annotations to ensure accuracy and completeness. Make sure all cars (excluding taxis) and trees are labeled correctly and that the bounding boxes or polygons are precise.',
#     'Image_Example': 'review_annotations.jpg'},
#    {'Step_Number': '7',
#     'Description': 'Save and Submit',
#     'Instructions': 'Save the annotated image in the designated format and submit it through the appropriate channel for review or inclusion in the dataset.',
#     'Image_Example': 'save_and_submit.jpg'}],
#   'Responsibilities': {'Image Annotator': 'Responsible for accurately identifying and annotating cars and trees in images according to the guidelines provided in this SOP.',
#    'Quality Assurance': 'Responsible for reviewing annotated images to ensure they meet the dataset criteria and SOP standards.'},
#   'Documentation': {'Annotation Logs': "A record of annotated images, including the annotator's name, date of annotation, number of objects labeled, and any notes or issues encountered during the process.",
#    'Review Records': 'A log of quality assurance reviews, including feedback and any required corrections to annotated images.'},
#   'Review': {'Frequency': 'This SOP should be reviewed bi-annually or whenever there is a change in annotation guidelines or tools.',
#    'Method': 'The review will be conducted by the annotation team lead in collaboration with the quality assurance department.'}}}

# %% [markdown]
# ### Step 4: Converting JSON response into a flattened pandas dataframe

# %%
try:
     df = json_normalize(json_response, record_path=['SOP_Table','rows'])

except:   
     df = json_normalize(json_response, record_path=['SOP_Table','Procedure'])

# %%
df
# Out:
#   Step_Number           Description  \
# 0           1  Open Annotation Tool
# 1           2      Identify Objects
# 2           3         Annotate Cars
# 3           4        Annotate Trees
# 4           5         Exclude Taxis
# 5           6    Review Annotations
# 6           7       Save and Submit
#
#                                         Instructions             Image_Example
# 0  Launch the image annotation software and load ...  open_annotation_tool.jpg
# 1  Carefully examine the image to identify all in...      identify_objects.jpg
# 2  Use the 'Car' label to annotate all vehicles t...         annotate_cars.jpg
# 3  Use the 'Tree' label to annotate all visible t...        annotate_trees.jpg
# 4  Do not annotate taxis. Taxis can typically be ...         exclude_taxis.jpg
# 5  Review all annotations to ensure accuracy and ...    review_annotations.jpg
# 6  Save the annotated image in the designated for...       save_and_submit.jpg

# %% [markdown]
# ### Step 5: Now to generate images for each step - essentially this is suppose to be a visual aid to perform the task more accurately

# %%
# let's start by writing a simple function to generate the images for each step

def GetImages(image_description: str):
    response = client.images.generate(
        model="dall-e-3",
        prompt=image_description,
        size="1024x1024",
        quality="standard",
        n=1,
    )

    time.sleep(5)

    return response.data[0].url

# %%
# next let us now join the description strings from our df to create the prompts for image generation

df["image_prompt"] = df[df.columns.to_list()[1:]]\
    .apply(lambda x: "Generate image where " + x[0] + ". " + x[1] + ". Name the image as " + x[2], axis=1)

df
# Out:
#   Step_Number           Description  \
# 0           1  Open Annotation Tool
# 1           2      Identify Objects
# 2           3         Annotate Cars
# 3           4        Annotate Trees
# 4           5         Exclude Taxis
# 5           6    Review Annotations
# 6           7       Save and Submit
#
#                                         Instructions  \
# 0  Launch the image annotation software and load ...
# 1  Carefully examine the image to identify all in...
# 2  Use the 'Car' label to annotate all vehicles t...
# 3  Use the 'Tree' label to annotate all visible t...
# 4  Do not annotate taxis. Taxis can typically be ...
# 5  Review all annotations to ensure accuracy and ...
# 6  Save the annotated image in the designated for...
#
#               Image_Example                                       image_prompt
# 0  open_annotation_tool.jpg  Generate image where Open Annotation Tool. Lau...
# 1      identify_objects.jpg  Generate image where Identify Objects. Careful...
# 2         annotate_cars.jpg  Generate image where Annotate Cars. Use the 'C...
# 3        annotate_trees.jpg  Generate image where Annotate Trees. Use the '...
# 4         exclude_taxis.jpg  Generate image where Exclude Taxis. Do not ann...
# 5    review_annotations.jpg  Generate image where Review Annotations. Revie...
# 6       save_and_submit.jpg  Generate image where Save and Submit. Save the...

# %%
# now to generate the urls for the images

df['Example'] = df['image_prompt'].progress_apply(GetImages)

df
# Out:
# 100%|██████████| 7/7 [02:21<00:00, 20.23s/it]
#   Step_Number           Description  \
# 0           1  Open Annotation Tool
# 1           2      Identify Objects
# 2           3         Annotate Cars
# 3           4        Annotate Trees
# 4           5         Exclude Taxis
# 5           6    Review Annotations
# 6           7       Save and Submit
#
#                                         Instructions  \
# 0  Launch the image annotation software and load ...
# 1  Carefully examine the image to identify all in...
# 2  Use the 'Car' label to annotate all vehicles t...
# 3  Use the 'Tree' label to annotate all visible t...
# 4  Do not annotate taxis. Taxis can typically be ...
# 5  Review all annotations to ensure accuracy and ...
# 6  Save the annotated image in the designated for...
#
#               Image_Example  \
# 0  open_annotation_tool.jpg
# 1      identify_objects.jpg
# 2         annotate_cars.jpg
# 3        annotate_trees.jpg
# 4         exclude_taxis.jpg
# 5    review_annotations.jpg
# 6       save_and_submit.jpg
#
#                                         image_prompt  \
# 0  Generate image where Open Annotation Tool. Lau...
# 1  Generate image where Identify Objects. Careful...
# 2  Generate image where Annotate Cars. Use the 'C...
# 3  Generate image where Annotate Trees. Use the '...
# 4  Generate image where Exclude Taxis. Do not ann...
# 5  Generate image where Review Annotations. Revie...
# 6  Generate image where Save and Submit. Save the...
#
#                                              Example
# 0  https://oaidalleapiprodscus.blob.core.windows....
# 1  https://oaidalleapiprodscus.blob.core.windows....
# 2  https://oaidalleapiprodscus.blob.core.windows....
# 3  https://oaidalleapiprodscus.blob.core.windows....
# 4  https://oaidalleapiprodscus.blob.core.windows....
# 5  https://oaidalleapiprodscus.blob.core.windows....
# 6  https://oaidalleapiprodscus.blob.core.windows....

# %% [markdown]
# ### Step 6: Now that we have the image URLs, we now need to render the images in the dataframe

# %%
# moving forward, we now want to convert the image URLs into actual images displated in the dataframe

# Converting links to html tags
def path_to_image_html(path):
    return '<img src="'+ path + '" width="120" >'

# Rendering the images in the dataframe using the HTML method.
HTML(df.to_html(escape=False,formatters=dict(Example=path_to_image_html)))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Step_Number</th>
#       <th>Description</th>
#       <th>Instructions</th>
#       <th>Image_Example</th>
#       <th>image_prompt</th>
#       <th>Example</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>Open Annotation Tool</td>
#       <td>Launch the image annotation software and load the image to be annotated.</td>
#       <td>open_annotation_tool.jpg</td>
#       <td>Generate image where Open Annotation Tool. Launch the image annotation software and load the image to be annotated.. Name the image as open_annotation_tool.jpg</td>
#       <td><img src="https://oaidalleapiprodscus.blob.core.windows.net/private/org-Pzwaj2iF9vX70guDVIDpMNlx/user-przJTvyPtKSAMFVgep6sMi8C/img-E08Gzt8i31Eor5Aq7GZRuQmx.png?st=2023-12-19T06%3A23%3A01Z&se=2023-12-19T08%3A23%3A01Z&sp=r&sv=2021-08-06&sr=b&rscd=inline&rsct=image/png&skoid=6aaadede-4fb3-4698-a8f6-684d7786b067&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2023-12-19T01%3A05%3A49Z&ske=2023-12-20T01%3A05%3A49Z&sks=b&skv=2021-08-06&sig=wdC3kcl8YjjpN3zmn9enOl0GHiEZqyIXHVs8wFGkYRE%3D" width="120" ></td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2</td>
#       <td>Identify Objects</td>
#       <td>Carefully examine the image to identify all instances of cars and trees. Remember not to annotate taxis as cars.</td>
#       <td>identify_objects.jpg</td>
#       <td>Generate image where Identify Objects. Carefully examine the image to identify all instances of cars and trees. Remember not to annotate taxis as cars.. Name the image as identify_objects.jpg</td>
#       <td><img src="https://oaidalleapiprodscus.blob.core.windows.net/private/org-Pzwaj2iF9vX70guDVIDpMNlx/user-przJTvyPtKSAMFVgep6sMi8C/img-qAJc1yayTBfZ4yMhN52vAJb8.png?st=2023-12-19T06%3A23%3A18Z&se=2023-12-19T08%3A23%3A18Z&sp=r&sv=2021-08-06&sr=b&rscd=inline&rsct=image/png&skoid=6aaadede-4fb3-4698-a8f6-684d7786b067&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2023-12-19T01%3A07%3A13Z&ske=2023-12-20T01%3A07%3A13Z&sks=b&skv=2021-08-06&sig=u3kRX14UiiCPv3l7NKF7%2B1nmL7KAG/WRIAowLkDBx9Q%3D" width="120" ></td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>3</td>
#       <td>Annotate Cars</td>
#       <td>Use the 'Car' label to annotate all vehicles that are not taxis. Draw a bounding box around each car, ensuring it fits the object as closely as possible without including background elements.</td>
#       <td>annotate_cars.jpg</td>
#       <td>Generate image where Annotate Cars. Use the 'Car' label to annotate all vehicles that are not taxis. Draw a bounding box around each car, ensuring it fits the object as closely as possible without including background elements.. Name the image as annotate_cars.jpg</td>
#       <td><img src="https://oaidalleapiprodscus.blob.core.windows.net/private/org-Pzwaj2iF9vX70guDVIDpMNlx/user-przJTvyPtKSAMFVgep6sMi8C/img-UKnTQIWFPc4YY6qzO0jtIAow.png?st=2023-12-19T06%3A23%3A34Z&se=2023-12-19T08%3A23%3A34Z&sp=r&sv=2021-08-06&sr=b&rscd=inline&rsct=image/png&skoid=6aaadede-4fb3-4698-a8f6-684d7786b067&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2023-12-19T01%3A05%3A15Z&ske=2023-12-20T01%3A05%3A15Z&sks=b&skv=2021-08-06&sig=QDG8n6zEroDBKee8jmgEEMiPfElUqGn8PF0LGxzqmbc%3D" width="120" ></td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>4</td>
#       <td>Annotate Trees</td>
#       <td>Use the 'Tree' label to annotate all visible trees in the image. Draw a bounding box or use polygonal segmentation to outline the full extent of the tree, including branches and foliage.</td>
#       <td>annotate_trees.jpg</td>
#       <td>Generate image where Annotate Trees. Use the 'Tree' label to annotate all visible trees in the image. Draw a bounding box or use polygonal segmentation to outline the full extent of the tree, including branches and foliage.. Name the image as annotate_trees.jpg</td>
#       <td><img src="https://oaidalleapiprodscus.blob.core.windows.net/private/org-Pzwaj2iF9vX70guDVIDpMNlx/user-przJTvyPtKSAMFVgep6sMi8C/img-Q3lkymwuy7DOyc0ZV6mr5vpx.png?st=2023-12-19T06%3A23%3A54Z&se=2023-12-19T08%3A23%3A54Z&sp=r&sv=2021-08-06&sr=b&rscd=inline&rsct=image/png&skoid=6aaadede-4fb3-4698-a8f6-684d7786b067&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2023-12-19T01%3A05%3A57Z&ske=2023-12-20T01%3A05%3A57Z&sks=b&skv=2021-08-06&sig=kVcLtnpWDPu%2BWLYpen1U0u7hpH3JrZap6uXHrtXkrjI%3D" width="120" ></td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>5</td>
#       <td>Exclude Taxis</td>
#       <td>Do not annotate taxis. Taxis can typically be identified by their distinct color (often yellow) and markings. If unsure, refer to local taxi identification guidelines.</td>
#       <td>exclude_taxis.jpg</td>
#       <td>Generate image where Exclude Taxis. Do not annotate taxis. Taxis can typically be identified by their distinct color (often yellow) and markings. If unsure, refer to local taxi identification guidelines.. Name the image as exclude_taxis.jpg</td>
#       <td><img src="https://oaidalleapiprodscus.blob.core.windows.net/private/org-Pzwaj2iF9vX70guDVIDpMNlx/user-przJTvyPtKSAMFVgep6sMi8C/img-0loQ2M2pez2nJZq5hRYavHfP.png?st=2023-12-19T06%3A24%3A16Z&se=2023-12-19T08%3A24%3A16Z&sp=r&sv=2021-08-06&sr=b&rscd=inline&rsct=image/png&skoid=6aaadede-4fb3-4698-a8f6-684d7786b067&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2023-12-19T01%3A08%3A19Z&ske=2023-12-20T01%3A08%3A19Z&sks=b&skv=2021-08-06&sig=H70mwerEGK%2B9C62hBa4Z2B3uzqssbhhiYeZkULGMi4k%3D" width="120" ></td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>6</td>
#       <td>Review Annotations</td>
#       <td>Review all annotations to ensure accuracy and completeness. Make sure all cars (excluding taxis) and trees are labeled correctly and that the bounding boxes or polygons are precise.</td>
#       <td>review_annotations.jpg</td>
#       <td>Generate image where Review Annotations. Review all annotations to ensure accuracy and completeness. Make sure all cars (excluding taxis) and trees are labeled correctly and that the bounding boxes or polygons are precise.. Name the image as review_annotations.jpg</td>
#       <td><img src="https://oaidalleapiprodscus.blob.core.windows.net/private/org-Pzwaj2iF9vX70guDVIDpMNlx/user-przJTvyPtKSAMFVgep6sMi8C/img-vbgmAT1qFCCQ5HP2K2JtCisX.png?st=2023-12-19T06%3A24%3A30Z&se=2023-12-19T08%3A24%3A30Z&sp=r&sv=2021-08-06&sr=b&rscd=inline&rsct=image/png&skoid=6aaadede-4fb3-4698-a8f6-684d7786b067&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2023-12-19T01%3A07%3A42Z&ske=2023-12-20T01%3A07%3A42Z&sks=b&skv=2021-08-06&sig=mazmE/312pKav1ECR/sXiilUd5sTAolQXjhL9T0uV2w%3D" width="120" ></td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>7</td>
#       <td>Save and Submit</td>
#       <td>Save the annotated image in the designated format and submit it through the appropriate channel for review or inclusion in the dataset.</td>
#       <td>save_and_submit.jpg</td>
#       <td>Generate image where Save and Submit. Save the annotated image in the designated format and submit it through the appropriate channel for review or inclusion in the dataset.. Name the image as save_and_submit.jpg</td>
#       <td><img src="https://oaidalleapiprodscus.blob.core.windows.net/private/org-Pzwaj2iF9vX70guDVIDpMNlx/user-przJTvyPtKSAMFVgep6sMi8C/img-cazJDeIIWvc0WEqNdKmE2jmc.png?st=2023-12-19T06%3A24%3A47Z&se=2023-12-19T08%3A24%3A47Z&sp=r&sv=2021-08-06&sr=b&rscd=inline&rsct=image/png&skoid=6aaadede-4fb3-4698-a8f6-684d7786b067&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2023-12-19T01%3A06%3A27Z&ske=2023-12-20T01%3A06%3A27Z&sks=b&skv=2021-08-06&sig=fjEKeSWfXe3k%2BWz4gdnQKtgja/LE/upe8KiiPK3BEcM%3D" width="120" ></td>
#     </tr>
#   </tbody>
# </table>

# %%
# We no longer need to the image prompt column, we can drop it
df.drop(columns=['image_prompt'], inplace=True)

df_html = df.to_html(escape=False,
                     formatters=dict(Example=path_to_image_html),
                     index=False)

print(df_html)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Step_Number</th>
#       <th>Description</th>
#       <th>Instructions</th>
#       <th>Image_Example</th>
#       <th>Example</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>Open Annotation Tool</td>
#       <td>Launch the image annotation software and load the image to be annotated.</td>
#       <td>open_annotation_tool.jpg</td>
#       <td><img src="https://oaidalleapiprodscus.blob.core.windows.net/private/org-Pzwaj2iF9vX70guDVIDpMNlx/user-przJTvyPtKSAMFVgep6sMi8C/img-E08Gzt8i31Eor5Aq7GZRuQmx.png?st=2023-12-19T06%3A23%3A01Z&se=2023-12-19T08%3A23%3A01Z&sp=r&sv=2021-08-06&sr=b&rscd=inline&rsct=image/png&skoid=6aaadede-4fb3-4698-a8f6-684d7786b067&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2023-12-19T01%3A05%3A49Z&ske=2023-12-20T01%3A05%3A49Z&sks=b&skv=2021-08-06&sig=wdC3kcl8YjjpN3zmn9enOl0GHiEZqyIXHVs8wFGkYRE%3D" width="120" ></td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>Identify Objects</td>
#       <td>Carefully examine the image to identify all instances of cars and trees. Remember not to annotate taxis as cars.</td>
#       <td>identify_objects.jpg</td>
#       <td><img src="https://oaidalleapiprodscus.blob.core.windows.net/private/org-Pzwaj2iF9vX70guDVIDpMNlx/user-przJTvyPtKSAMFVgep6sMi8C/img-qAJc1yayTBfZ4yMhN52vAJb8.png?st=2023-12-19T06%3A23%3A18Z&se=2023-12-19T08%3A23%3A18Z&sp=r&sv=2021-08-06&sr=b&rscd=inline&rsct=image/png&skoid=6aaadede-4fb3-4698-a8f6-684d7786b067&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2023-12-19T01%3A07%3A13Z&ske=2023-12-20T01%3A07%3A13Z&sks=b&skv=2021-08-06&sig=u3kRX14UiiCPv3l7NKF7%2B1nmL7KAG/WRIAowLkDBx9Q%3D" width="120" ></td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>Annotate Cars</td>
#       <td>Use the 'Car' label to annotate all vehicles that are not taxis. Draw a bounding box around each car, ensuring it fits the object as closely as possible without including background elements.</td>
#       <td>annotate_cars.jpg</td>
#       <td><img src="https://oaidalleapiprodscus.blob.core.windows.net/private/org-Pzwaj2iF9vX70guDVIDpMNlx/user-przJTvyPtKSAMFVgep6sMi8C/img-UKnTQIWFPc4YY6qzO0jtIAow.png?st=2023-12-19T06%3A23%3A34Z&se=2023-12-19T08%3A23%3A34Z&sp=r&sv=2021-08-06&sr=b&rscd=inline&rsct=image/png&skoid=6aaadede-4fb3-4698-a8f6-684d7786b067&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2023-12-19T01%3A05%3A15Z&ske=2023-12-20T01%3A05%3A15Z&sks=b&skv=2021-08-06&sig=QDG8n6zEroDBKee8jmgEEMiPfElUqGn8PF0LGxzqmbc%3D" width="120" ></td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>Annotate Trees</td>
#       <td>Use the 'Tree' label to annotate all visible trees in the image. Draw a bounding box or use polygonal segmentation to outline the full extent of the tree, including branches and foliage.</td>
#       <td>annotate_trees.jpg</td>
#       <td><img src="https://oaidalleapiprodscus.blob.core.windows.net/private/org-Pzwaj2iF9vX70guDVIDpMNlx/user-przJTvyPtKSAMFVgep6sMi8C/img-Q3lkymwuy7DOyc0ZV6mr5vpx.png?st=2023-12-19T06%3A23%3A54Z&se=2023-12-19T08%3A23%3A54Z&sp=r&sv=2021-08-06&sr=b&rscd=inline&rsct=image/png&skoid=6aaadede-4fb3-4698-a8f6-684d7786b067&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2023-12-19T01%3A05%3A57Z&ske=2023-12-20T01%3A05%3A57Z&sks=b&skv=2021-08-06&sig=kVcLtnpWDPu%2BWLYpen1U0u7hpH3JrZap6uXHrtXkrjI%3D" width="120" ></td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>Exclude Taxis</td>
#       <td>Do not annotate taxis. Taxis can typically be identified by their distinct color (often yellow) and markings. If unsure, refer to local taxi identification guidelines.</td>
#       <td>exclude_taxis.jpg</td>
#       <td><img src="https://oaidalleapiprodscus.blob.core.windows.net/private/org-Pzwaj2iF9vX70guDVIDpMNlx/user-przJTvyPtKSAMFVgep6sMi8C/img-0loQ2M2pez2nJZq5hRYavHfP.png?st=2023-12-19T06%3A24%3A16Z&se=2023-12-19T08%3A24%3A16Z&sp=r&sv=2021-08-06&sr=b&rscd=inline&rsct=image/png&skoid=6aaadede-4fb3-4698-a8f6-684d7786b067&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2023-12-19T01%3A08%3A19Z&ske=2023-12-20T01%3A08%3A19Z&sks=b&skv=2021-08-06&sig=H70mwerEGK%2B9C62hBa4Z2B3uzqssbhhiYeZkULGMi4k%3D" width="120" ></td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>Review Annotations</td>
#       <td>Review all annotations to ensure accuracy and completeness. Make sure all cars (excluding taxis) and trees are labeled correctly and that the bounding boxes or polygons are precise.</td>
#       <td>review_annotations.jpg</td>
#       <td><img src="https://oaidalleapiprodscus.blob.core.windows.net/private/org-Pzwaj2iF9vX70guDVIDpMNlx/user-przJTvyPtKSAMFVgep6sMi8C/img-vbgmAT1qFCCQ5HP2K2JtCisX.png?st=2023-12-19T06%3A24%3A30Z&se=2023-12-19T08%3A24%3A30Z&sp=r&sv=2021-08-06&sr=b&rscd=inline&rsct=image/png&skoid=6aaadede-4fb3-4698-a8f6-684d7786b067&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2023-12-19T01%3A07%3A42Z&ske=2023-12-20T01%3A07%3A42Z&sks=b&skv=2021-08-06&sig=mazmE/312pKav1ECR/sXiilUd5sTAolQXjhL9T0uV2w%3D" width="120" ></td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>Save and Submit</td>
#       <td>Save the annotated image in the designated format and submit it through the appropriate channel for review or inclusion in the dataset.</td>
#       <td>save_and_submit.jpg</td>
#       <td><img src="https://oaidalleapiprodscus.blob.core.windows.net/private/org-Pzwaj2iF9vX70guDVIDpMNlx/user-przJTvyPtKSAMFVgep6sMi8C/img-cazJDeIIWvc0WEqNdKmE2jmc.png?st=2023-12-19T06%3A24%3A47Z&se=2023-12-19T08%3A24%3A47Z&sp=r&sv=2021-08-06&sr=b&rscd=inline&rsct=image/png&skoid=6aaadede-4fb3-4698-a8f6-684d7786b067&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2023-12-19T01%3A06%3A27Z&ske=2023-12-20T01%3A06%3A27Z&sks=b&skv=2021-08-06&sig=fjEKeSWfXe3k%2BWz4gdnQKtgja/LE/upe8KiiPK3BEcM%3D" width="120" ></td>
#     </tr>
#   </tbody>
# </table>

# %%
try:
     summary = json_normalize(json_response)
     summary.drop(columns='SOP_Table.Procedure_Steps', inplace=True)

except:
     summary = json_normalize(json_response)
     summary.drop(columns='SOP_Table.Procedure', inplace=True)

# %%
summary.columns = [re.sub("^(.*\.)", "", col) for col in summary.columns]

summary
# Out:
#                                                Title  \
# 0  Standard Operating Procedure for Image Annotation
#
#                                              Purpose  \
# 0  To provide clear guidelines for annotating ima...
#
#                                                Scope  \
# 0  This SOP applies to all image annotators taske...
#
#                                      Image Annotator  \
# 0  Responsible for accurately identifying and ann...
#
#                                    Quality Assurance  \
# 0  Responsible for reviewing annotated images to ...
#
#                                      Annotation Logs  \
# 0  A record of annotated images, including the an...
#
#                                       Review Records  \
# 0  A log of quality assurance reviews, including ...
#
#                                            Frequency  \
# 0  This SOP should be reviewed bi-annually or whe...
#
#                                               Method
# 0  The review will be conducted by the annotation...

# %%
summary_html = summary.to_html(index=False)

print(summary_html)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Title</th>
#       <th>Purpose</th>
#       <th>Scope</th>
#       <th>Image Annotator</th>
#       <th>Quality Assurance</th>
#       <th>Annotation Logs</th>
#       <th>Review Records</th>
#       <th>Frequency</th>
#       <th>Method</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>Standard Operating Procedure for Image Annotation</td>
#       <td>To provide clear guidelines for annotating images with cars and trees while excluding taxis from the car category.</td>
#       <td>This SOP applies to all image annotators tasked with labeling images for machine learning and computer vision training datasets.</td>
#       <td>Responsible for accurately identifying and annotating cars and trees in images according to the guidelines provided in this SOP.</td>
#       <td>Responsible for reviewing annotated images to ensure they meet the dataset criteria and SOP standards.</td>
#       <td>A record of annotated images, including the annotator's name, date of annotation, number of objects labeled, and any notes or issues encountered during the process.</td>
#       <td>A log of quality assurance reviews, including feedback and any required corrections to annotated images.</td>
#       <td>This SOP should be reviewed bi-annually or whenever there is a change in annotation guidelines or tools.</td>
#       <td>The review will be conducted by the annotation team lead in collaboration with the quality assurance department.</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Step 7: Now to merge both summary html and instruction html in one html page

# %%
# Merge HTML content with a gap between tables
merged_html_content = f"""
<!DOCTYPE html>
<html>
<head>
    <style>
        .table-container {{
            margin-bottom: 50px;  /* Adjust the gap between tables */
        }}

        table {{
            border-collapse: collapse;
            width: 50%;
            margin: 20px;
        }}
        th, td {{
            border: 1px solid black;
            padding: 20px;
            text-align: left;
        }}
        h2 {{
            color: blue;
        }}

        body {{ background-color: #e0e0e0; }}
    </style>
</head>
<body>
    <h2>Responsibilities and Governance</h2>
        {summary_html}
    <h2>Instructions and Guidelines</h2>
        {df_html}
    </div>
</body>
</html>
"""


# Save the merged HTML content into a new file
with open("Data_Annotation_SOP.html", "w") as merged_file:
    merged_file.write(merged_html_content)
